# %% [markdown]
# <a href="https://colab.research.google.com/github/FatemehSadeghi9/Forkify-1/blob/master/my_experience.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time

# %%
print(time.ctime())
# Out:
# Wed Feb 12 13:55:20 2025

# %%
print(time.ctime())
time.sleep(5)
print(time.ctime())
# Out:
# Wed Feb 12 13:55:20 2025
# Wed Feb 12 13:55:25 2025

# %% [markdown]
# **helloooo**
# *hello*
# ~hello~

# %% [markdown]
# $\sqrt{3x-1}+(1+x)^2$
